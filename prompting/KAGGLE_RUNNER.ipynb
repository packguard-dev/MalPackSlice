# %%
ls

# %%
# !git clone https://github.com/Nguyen-Dang-Khoa-04072004/MalLLM.git
# Out:
# fatal: destination path 'MalLLM' already exists and is not an empty directory.

# %%
# !git checkout DeepSeek-Coder-6.7b-Kaggle
# Out:
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !pip install -r requirements.txt

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
secret_value_0 = user_secrets.get_secret("GITHUB_SECRET")  # PAT của user Nguyen-Dang-Khoa-04072004

import os
os.environ["GIT_TOKEN"] = secret_value_0


# !git config user.name "Nguyen-Dang-Khoa-04072004"
# !git config user.email ""


# !git remote set-url origin https://Nguyen-Dang-Khoa-04072004:${GIT_TOKEN}@github.com/Nguyen-Dang-Khoa-04072004/MalLLM.git
# !git add -A
# !git commit -m "Kaggle Runner Commit"
# !git push -u origin DeepSeek-Coder-6.7b-Kaggle
# Out:
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !python main.py

# !git add .
# !git commit -m "Kaggle Runner Commit"
# !git push
# Out:
# python3: can't open file '/kaggle/working/main.py': [Errno 2] No such file or directory
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
